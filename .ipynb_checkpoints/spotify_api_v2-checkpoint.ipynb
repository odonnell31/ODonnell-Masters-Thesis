# %% [markdown]
# ## Resource Enabled Spotify Client

# %%
import requests
import base64
import datetime
import pandas as pd
from urllib.parse import urlencode
import json

# %%
# from https://developer.spotify.com/dashboard/applications/12e3a84c48794da1b01d8c83894b9b22
client_id = '12e3a84c48794da1b01d8c83894b9b22'
client_secret = 'a83d66bf68004a038c4d83eb110e547d'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        
        if client_secret == None or client_id == None:
            raise Exception("you must set client_id and client_secret")
        
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        
        return {
            'Authorization': f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            'grant_type': 'client_credentials'
        }
        
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_url, data = token_data, headers = token_headers)

        if r.status_code not in range(200,299):
            raise Exception("Could not authenticate client..")
            # return False
        
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
            
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            'Authorization': f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type = 'shows', version='v1', market = 'US'):
        if resource_type == 'shows':
            endpoint = f"https://api.spotify.com/{version}/shows/{lookup_id}/episodes"
        else:
            endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        #endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        print(lookup)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
            
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_episodes(self, _id):
        return self.get_resource(_id, resource_type='shows')
    
    #def get_show(self, _id):
    #    return self.get_resource(_id, resource_type='shows')
    
    def search(self, query, search_type = 'artists', market = 'US'): #type is built-in python operator
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({'q': query, 'type': search_type.lower(), 'market': market})
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers = headers)
        if r.status_code not in range(200,299):
            return "somethings wrong"
        return r.json()
    
    def get_podcast_info_by_id(self, showid, market = 'US'): #type is built-in python operator
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/shows"
        data = urlencode({'ids': showid, "market": market})
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers = headers)
        if r.status_code not in range(200,299):
            return "somethings wrong"
        
        raw_json = r.json()
        
        podcast_dict = {'name': raw_json['shows'][0]['name'],
            'publisher': raw_json['shows'][0]['publisher'],
            'total_episodes': raw_json['shows'][0]['total_episodes'],
            'id': raw_json['shows'][0]['id'],
            'media_type': raw_json['shows'][0]['media_type'],
            'description': raw_json['shows'][0]['description'],
            'external_urls': raw_json['shows'][0]['external_urls'],
            'languages': raw_json['shows'][0]['languages'],
            'uri': raw_json['shows'][0]['uri']}
        
        return podcast_dict
    
    
    def get_podcast_episodes_by_id(self, showid, market = 'US'): #type is built-in python operator
        headers = self.get_resource_header()
        endpoint = f"https://api.spotify.com/v1/shows/{showid}/episodes?offset=1&limit=10&market=US"
        data = urlencode({'ids': showid, "market": market})
        lookup_url = f"{endpoint}"
        print(lookup_url)
        r = requests.get(lookup_url, headers = headers)
        if r.status_code not in range(200,299):
            return "somethings wrong"
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %% [markdown]
# ## list of working methods:
# - search
# - get_podcast_info_by_id

# %%
# search for podcast/artist/album/track/episode by name
spotify.search('Bill Simmons Pod', search_type = "show")
# Out:
# https://api.spotify.com/v1/search?q=Bill+Simmons+Pod&type=show&market=US
# {'shows': {'href': 'https://api.spotify.com/v1/search?query=Bill+Simmons+Pod&type=show&market=US&offset=0&limit=20',
#   'items': [{'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "HBO and The Ringer's Bill Simmons hosts the most downloaded sports podcast of all time, with a rotating crew of celebrities, athletes, and media staples, as well as mainstays like Cousin Sal, Joe House, and a slew of other friends and family members who always happen to be suspiciously available.",
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/07SjDmKb9iliEzpNcN2xGD'},
#     'href': 'https://api.spotify.com/v1/shows/07SjDmKb9iliEzpNcN2xGD',
#     'id': '07SjDmKb9iliEzpNcN2xGD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Bill Simmons Podcast',
#     'publisher': 'The Ringer & Bill Simmons',
#     'total_episodes': 708,
#     'type': 'show',
#     'uri': 'spotify:show:07SjDmKb9iliEzpNcN2xGD'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "In no way affiliated with the Bill Simmons Podcast from the CEO of The Ringer, this weekly (?) show is an irreverent skewering of the previous week's episodes of the BSPod. Knife_guy approved (but he's washed anyway).  Support this podcast: https://anchor.fm/billsimmonspodcastpodcast/support",
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/6712kYfaN3dHZSYmiKx1OG'},
#     'href': 'https://api.spotify.com/v1/shows/6712kYfaN3dHZSYmiKx1OG',
#     'id': '6712kYfaN3dHZSYmiKx1OG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6430ac4447ef65969f731bc5e929f8560df2fe85',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/40258521aa035dd7078a9246e6e33426791e78fd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/bd67505fa091beb12820e64398ae84e80a055615',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Bill Simmons Podcast Podcast',
#     'publisher': 'Chris and Matt',
#     'total_episodes': 76,
#     'type': 'show',
#     'uri': 'spotify:show:6712kYfaN3dHZSYmiKx1OG'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "The Rewatchables,' a film podcast from the Ringer Podcast Network, features The Ringer’s Bill Simmons and a roundtable of people from The Ringer universe discussing movies they can’t seem to stop watching. Support this podcast: https://anchor.fm/sergio-lahm/support",
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/7DTdEFIZETTodfQaAIICW5'},
#     'href': 'https://api.spotify.com/v1/shows/7DTdEFIZETTodfQaAIICW5',
#     'id': '7DTdEFIZETTodfQaAIICW5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b4b4d84cc56463c757a8cee96c793202a5d89edf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2537999c7675e74b52372922803b53de6ebbd11c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5a0bd85751321178d8ab9a2cbf15f2763ceb76c6',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Rewatchables – The Ringer & Bill Simmons ',
#     'publisher': 'sergio lahm',
#     'total_episodes': 10,
#     'type': 'show',
#     'uri': 'spotify:show:7DTdEFIZETTodfQaAIICW5'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "'The Rewatchables,' a film podcast from the Ringer Podcast Network, features The Ringer’s Bill Simmons and a roundtable of people from The Ringer universe discussing movies they can’t seem to stop watching.",
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/1lUPomulZRPquVAOOd56EW'},
#     'href': 'https://api.spotify.com/v1/shows/1lUPomulZRPquVAOOd56EW',
#     'id': '1lUPomulZRPquVAOOd56EW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/54dc479bf6104323c8822ffabf9b9be0ff4639d4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/c9c2626441532f86090880d4371fd005958d50cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/c168281adc04db1c355d78a944509e3e2d5b7a63',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Rewatchables',
#     'publisher': 'The Ringer & Bill Simmons',
#     'total_episodes': 148,
#     'type': 'show',
#     'uri': 'spotify:show:1lUPomulZRPquVAOOd56EW'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'Billy Willig plays bass in the pop-punk band LIKE MIKE. He also performs stand up comedy.  Cover art by Justin Simmonds',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/4u7vFUecr2KbGZK9fkorDC'},
#     'href': 'https://api.spotify.com/v1/shows/4u7vFUecr2KbGZK9fkorDC',
#     'id': '4u7vFUecr2KbGZK9fkorDC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a73d6b0cad548d5356bd7da70fcf4424b88edbf6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/fa216a1fc10b1456eeda34053319f5679e674c09',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/227c6cd40a787b7ee7dd23972e8740e13c9c814d',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': "Billy's Buck Wild Podcast",
#     'publisher': 'Billy Willig',
#     'total_episodes': 22,
#     'type': 'show',
#     'uri': 'spotify:show:4u7vFUecr2KbGZK9fkorDC'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'Welcome to the Supa Dupa Podcast featuring our host Rob Griggs. He’s from Chicago, went to school in Massachusetts, is the baby brother of two older sisters, and the older brother of his sister-niece. A father of triplets, he’s bad at painting, has flat feet, has a late problem and likes vanilla ice cream with M&Ms. His parents are from the South and he grew up on the South Side. His Mom’s fried chicken is better than anything you’ve ever had. He admires Diddy, Bill Simmons, Rob Dyrdek, and thinks Angela Rye is perfect. He’s a Bulls, Bears, and Sox fan. MJ is the GOAT. He’s a drummer and thinks Steph Curry is the greatest shooter. Ever.  So he’s the best person to talk about everything and nothing at the same time.  We hope you enjoy each episode because we had fun making them.  Please subscribe wherever you find your podcasts. This podcast is brought to you by HP53 Productions.  Follow the podcast on Instagram @supadupapod.',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/2BXBCB9rcvo8JvY51c6tQO'},
#     'href': 'https://api.spotify.com/v1/shows/2BXBCB9rcvo8JvY51c6tQO',
#     'id': '2BXBCB9rcvo8JvY51c6tQO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b20392aae6a50bfe647255210ad5f35b284c7b0b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f3e1d71d435e030bc500c8840a9e15247c0e5487',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/d4925bc1cc80915c28a9e8401d8a68b1af391cb8',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Supa Dupa Podcast',
#     'publisher': 'Rob Griggs',
#     'total_episodes': 15,
#     'type': 'show',
#     'uri': 'spotify:show:2BXBCB9rcvo8JvY51c6tQO'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'The Ringer dives into movies as Sean Fennessey sits down with Hollywood’s biggest filmmakers, breaks down the latest industry trends, handicaps the upcoming Oscars race, and reviews new films with Ringer colleagues like Shea Serrano, Amanda Dobbins, and Bill Simmons.',
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/6mTel3azvnK8isLs4VujvF'},
#     'href': 'https://api.spotify.com/v1/shows/6mTel3azvnK8isLs4VujvF',
#     'id': '6mTel3azvnK8isLs4VujvF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e84b33dc2fde71a62fd84ff05f7cc06e0c1193b1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/b89b4d8a67e902ccccf1d075ee135e7b1fe736bb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5226aca42c7a7c9fee625411dc8cec15bf2c16e3',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Big Picture',
#     'publisher': 'The Ringer',
#     'total_episodes': 291,
#     'type': 'show',
#     'uri': 'spotify:show:6mTel3azvnK8isLs4VujvF'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'Bill Simmons and his friends from The Ringer will debate, defend, and parse a controversial opinion on a pressing topic of the day. The takes cover timely matters from the worlds of sports, movie, TV, food, music, and the internet.',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/55R0CZoqgY3hcmCmVkmBig'},
#     'href': 'https://api.spotify.com/v1/shows/55R0CZoqgY3hcmCmVkmBig',
#     'id': '55R0CZoqgY3hcmCmVkmBig',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/252ef73615c1d575efd2a9916bb9eb567ea2f3f3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/7699333e2aac6be2dcf2d45de85425fa62f697e8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8de1611a0b0962822d381f4d883c559cb56bcadf',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Hottest Take',
#     'publisher': 'Spotify Studios',
#     'total_episodes': 98,
#     'type': 'show',
#     'uri': 'spotify:show:55R0CZoqgY3hcmCmVkmBig'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'The Greer Business 360 Podcast takes a deep dive into celebrating Greer, SC as an amazing place to do business; focusing on the strategy and leadership to have a thriving and profitable business.',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/0tMNSZ4K1K6uYxhLJrpMtF'},
#     'href': 'https://api.spotify.com/v1/shows/0tMNSZ4K1K6uYxhLJrpMtF',
#     'id': '0tMNSZ4K1K6uYxhLJrpMtF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e17efd80400f572d4e6f268e1e68f5bffc5eb801',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/304e7aea59b427279e35afcdc96895d6b41f2ac1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/d65499388772f8d5824b4061ceab013a57ed0df2',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en-US'],
#     'media_type': 'audio',
#     'name': 'Greer Business 360',
#     'publisher': 'Bill Simmons and Rick Stroud',
#     'total_episodes': 19,
#     'type': 'show',
#     'uri': 'spotify:show:0tMNSZ4K1K6uYxhLJrpMtF'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'Voted “Better than Bill Simmons” by people sometimes.   Email : thebasketballpc@gmail.com Follow on Twitter : @thebasketballpc Support this podcast: https://anchor.fm/basketballpodcast/support',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/3QY7A1q1Vf2DZRoLHscbO0'},
#     'href': 'https://api.spotify.com/v1/shows/3QY7A1q1Vf2DZRoLHscbO0',
#     'id': '3QY7A1q1Vf2DZRoLHscbO0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/1b34b3bd17bf1fe0af2d59d8d563009752b31242',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2cc3828b03627c11508936faeeb23ddabefb51ec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e03159819b5efc7383aab7547c6c48f6ba746cb4',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Basketball Podcast',
#     'publisher': 'Caleb Miller',
#     'total_episodes': 29,
#     'type': 'show',
#     'uri': 'spotify:show:3QY7A1q1Vf2DZRoLHscbO0'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': '        William Branham (1907-1965) was a Pentecostal minister from Jeffersonville, Indiana credited by some as initiating the Post WWII Healing Revival. The first of ten children of Charles and Ella Branham, Branham claimed to have been born in Cumberland County, KY and reared in the booming Southern Indiana casino town directly across the river from Louisville, KY. He was also a "doomsday Prophet", predicting several years that he claimed to be the End of Days.      When American Prohibition disrupted the thriving liquor industry of the local area, Branham\'s family became poor and destitute. Branham\'s father, employed as a driver for Otto Wathen of the R. E. Wathen Distilleries, was arrested for violation of the liquor laws, worsening their hardship. At the time, William was in critical condition in the Clark Memorial hospital after being shot. The Ku Klux Klan came to the rescue, paying his hospital bill and making an impact on his life that he would never forget.       Shortly after the Klan was exposed for taking control of the Indiana government, Roy E. Davis came to Jeffersonville claiming to be a Christian evangelist and becoming a choir leader for Ralph Rader. Davis was at one time an official spokesperson for William Joseph Simmons\' 1915 revival of the Klan, as well as a high-ranking member. He was also affiliated with other white supremacy groups Simmons created such as the "Knights Of The Flaming Sword." Shortly after being appointed as an elder of the Rader Gospel Tabernacle, past crimes of swindling, fraud, and multiple violations of underaged sex caught up with him. Davis was terminated from Rader\'s church, and started a Pentecostal church taking several members from Rader\'s congregation. It was at this Pentecostal church that Davis claims to have converted William Branham into his first Pentecostal Assembly. According to William Branham, Davis was his mentor, the one who baptized him, imparted the "Holy Ghost," and appointed him as a minister. Shortly after, Davis was extradited by the Governor of the State of Indiana to the casino town of Hot Springs, Arkansas on charges of grand theft and connection to murder. William Branham seized the opportunity, taking control of Davis\' rowdy church and forming the Billie Branham Pentecostal Tabernacle in 1936.       A year later, the 1937 Flood demolished the town of Jeffersonville. The once thriving casino town nicknamed "Little Vegas" that once attracted the likes of Al Capone and John Dillenger suddenly was leveled to a desolate wasteland. Later that year, Branham\'s first wife Hope died from a disease she contracted in January of 1936, and his daughter died shortly after.       In 1944, Roy E. Davis joined forces with former Congressman William D. Upshaw in an operation under the disguise of a children\'s orphanage in San Bernardino California. Soon after the orphanage was exposed for swindling thousands of dollars from the Los Angeles area and being the defendant in a highly publicized criminal lawsuit, Davis introduced Upshaw to William Branham. A year later, in 1945, William Branham began his evangelistic "healing" ministry, and Upshaw (who had witnessed been physically running since 1936) entered one of Branham\'s meetings as an "invalid" in a wheelchair. When Upshaw was "healed" from his "bedridden" condition, Branham\'s fame in the Faith Healing business quickly spread.       By 1947, William Branham had embellished many events of his "life story," removing the details that would raise skepticism and adding "supernatural" aspects.  He started claiming to have had several conflicting "commissions" by God, and introduced a tragic but partially fictional story of his life. Over time, his Stage Persona began to include stories of being born under a supernatural sign, having a prophetic gift as a toddler, fatherless at an early age, and more. Even the tragic death of his wife was embelished to become part of the story. It was such an intere ...
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/0G33AvACZMPUvxZxjtOlyV'},
#     'href': 'https://api.spotify.com/v1/shows/0G33AvACZMPUvxZxjtOlyV',
#     'id': '0G33AvACZMPUvxZxjtOlyV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/91fc0351f41043fdf624d8d9faafbc94dd3a32be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/b267c9ffc51dde840061365ee8bbf0dddff6431b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/42d5f926767d297936dd75a9248e0f3037de477c',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'William Branham Historical Research',
#     'publisher': 'John Collins',
#     'total_episodes': 50,
#     'type': 'show',
#     'uri': 'spotify:show:0G33AvACZMPUvxZxjtOlyV'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'The best sports talk around except for the Bill Simmons podcast',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/0mYb0EHOvnXEmyPGDxLxPJ'},
#     'href': 'https://api.spotify.com/v1/shows/0mYb0EHOvnXEmyPGDxLxPJ',
#     'id': '0mYb0EHOvnXEmyPGDxLxPJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/31554311b208d09e24b733d8fa31bf40c1d119bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6b260fcf90acfa71d459b1cc2620a3020bfcfbe7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8832784027d2f3ad0302e0873ad5e145dc549472',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'Spittin Sports',
#     'publisher': 'Jonah Grossman',
#     'total_episodes': 12,
#     'type': 'show',
#     'uri': 'spotify:show:0mYb0EHOvnXEmyPGDxLxPJ'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'The Fired Up Shows are a part of the BarnBurner Radio Network  Fired Up Shows are available on 122 Platforms.  Which are: Iheartradio Spotify   iTunes Soundcloud Google Play Sticher Tunein PodBean Zeno Media ZingoTV CastBox Speaker Anchor Pocket Casts Dogcatcher Radio Public Acast Breaker Audio Luminary Google Podcasts ESPNPOD Sport Podcasts BNS Sport RadioLab Cabin Radio Castro Podcasts Castback Cast Pod Podcast World Double Twist Podcast Addict Podcast Go Podcast Republic Sound Waves Wear Casts Capsule  Overcast PMCast   Fresh Cast Swoot Storiyoh Himalaya Player FM Moon FM Podcasty Podyssey IPoca Ferriss Podcast The Economist Podcast The Podcast Source Podcast Guru StarPodcast Pod Listen Freakonomics Podcast Quick World News ABC News Podcast Canada Podcast Canada Podcasts   American Podcast USA Podcast UK Podcast BBC Podcast CBCast CastMix Cast Mic NYtimes Podcast Guardian Podcast The Health Podcast Ivoxx My Source WeCast Knolo ShortOrange Omni Podcast English Podcast Tunevu G Podcast Dowloader Gom Audio Antenna Pod Double Pod BeyondPod Honey Pod LucidPod Playapod PodByte Podcatcher Daily Podcast Podcast Podcast+1 Podcast App Podcast Assist Podcast Hd Podcast Picker Podcast Player Podcast Tune Podcasts Tracker Podcoin  Procast  Podster-Podcast  PodKicker Simple Podcatcher Rss Feed Podcast Rise Pod CRT Podcast Paranormal PARANORMAL CaseFilePod MyMedia Oprah Podcast Bloomberg Podcast  Bill Simmons   UNV Podcast DJo Podcast DRK Podcast MED Podcast MyPOD Podcast Manager Radio.net Bullhorn myTurner Free Radios Canada Conversations Cast Podcast Video Maker  122 Total   Download the BarnBurner App On iOS & Android  Also a part of the OSG Sports App.  Download it on iOS & Android Devices.  Search BarnBurner & Also OSG Sports in their respective App Stores..  Also on ZingoTV Channel 250   The BarnBurner Radio Network is Available on ZingoTV Video Section  Download the ZingoTV App in their respective App Stores  Follow The BarnBurner Network on Social Media.  Facebook, Twitter, Instagram, Twitch,  Periscope, TikTok & Snapchat   @BarnBurnerNET  YouTube & Pintrest: @BarnBurner Network',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/6eKMWMEsUyDwUyof6nURZS'},
#     'href': 'https://api.spotify.com/v1/shows/6eKMWMEsUyDwUyof6nURZS',
#     'id': '6eKMWMEsUyDwUyof6nURZS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/56023ba75b0422b790a5ae69bee4320cefffd2a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/cdf1c6e611dfd2971dd709d406e321c651f408fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/eea179344135b5d3d332632b590d764fb9820252',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'Fired Up',
#     'publisher': 'BarnBurner Radio Network',
#     'total_episodes': 350,
#     'type': 'show',
#     'uri': 'spotify:show:6eKMWMEsUyDwUyof6nURZS'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'Presley, a 10-year old athlete from Las Vegas, NV, gives takes on sports and pop culture. An avid listener of Mina Kimes, Bill Simmons, and the hit show, "Pardon The Interruption," Presley\'s thoughts are both refreshing and fun. Check her out!',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/1w2dySkN3NSjON8gjyLc42'},
#     'href': 'https://api.spotify.com/v1/shows/1w2dySkN3NSjON8gjyLc42',
#     'id': '1w2dySkN3NSjON8gjyLc42',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/13e41d7831811b9da7a396f0bf8ca7b965fa2a2f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f2bb69276db096e557ba8010a84efc69af68eea8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a3b0eb847fe91c11e2f8e53c355b5110a8e5ca52',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Presley POD',
#     'publisher': 'SwagWag Productions',
#     'total_episodes': 1,
#     'type': 'show',
#     'uri': 'spotify:show:1w2dySkN3NSjON8gjyLc42'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'This is a fun, opinionated, and informative podcast. Guests to the show will bring alternative perspectives to keep the conversation fresh. Be prepared to receive a wealth of statistics to satisfy the appetite of a true NBA nerd. Similar to the Bill Simmons podcast and Jalen & Jacoby.',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/4U4ufJZ8OpNcMw92XRVbj6'},
#     'href': 'https://api.spotify.com/v1/shows/4U4ufJZ8OpNcMw92XRVbj6',
#     'id': '4U4ufJZ8OpNcMw92XRVbj6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/23ef4e296f04c88a3f836318fff3d37ba93acf90',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4fa0431629a9eb4d6311a39ee8d1f61b31b512c1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ac1c42a85f7b48f140a72377423dcfc0a299ef91',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en-US'],
#     'media_type': 'audio',
#     'name': 'The Sideline View Podcast',
#     'publisher': 'Jordan Greynolds',
#     'total_episodes': 21,
#     'type': 'show',
#     'uri': 'spotify:show:4U4ufJZ8OpNcMw92XRVbj6'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "Cover credit to Yuming Lu  The reason Frank (@hzblacksmith) and Charlie (@charlililiee) want to do a podcast is that they believe they know a lot about basketball and sports in general (like Bill Simmons, Zach Lowe, Nate Duncan, Ben Taylor etc.) and want to share their daily conversations with others.  二人对侃时以普通话为主，if there is a guest then it is mostly in English. It is an awesome opportunity for two Chinese to learn more about American culture and their American friends' backgrounds.  All opinions are their own. 所有言论仅代表二人立场",
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/6vV8HJur7WutTVuokRLvnC'},
#     'href': 'https://api.spotify.com/v1/shows/6vV8HJur7WutTVuokRLvnC',
#     'id': '6vV8HJur7WutTVuokRLvnC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/f9413d9a5aaee03475e0ca0a2442897f052df4a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/a798ba43f582adb2a6b5a6c6a204e2ed3d7d849f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/658be373867975aff924f9a79f0dcc1c3c4d1ba3',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': '打铁匠 The BlackSmith',
#     'publisher': 'Frank Li',
#     'total_episodes': 5,
#     'type': 'show',
#     'uri': 'spotify:show:6vV8HJur7WutTVuokRLvnC'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "Bill Simmons, Stephen A. Smith, Skip Bayless, what do these guys have in common? They're not me and I'm good. You could listen to all these folks pretend to know whats going on all you want, but if you want the real dish on Baskets you gotta come to me because I'll tell you right to your face that I don't know whats going on either. ",
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/4eDyBjB2iGCLMWsbx0iA8G'},
#     'href': 'https://api.spotify.com/v1/shows/4eDyBjB2iGCLMWsbx0iA8G',
#     'id': '4eDyBjB2iGCLMWsbx0iA8G',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/1544565d44660bd668c5e75d6da3b0f5751cb939',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/945573e6b5622ca174dc03c0d2a25be55d1a2bfd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/06f6e7fd21a40b0dd5c6993d526ce4ec5a657103',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'BasketTalk',
#     'publisher': 'Des Lombardo',
#     'total_episodes': 1,
#     'type': 'show',
#     'uri': 'spotify:show:4eDyBjB2iGCLMWsbx0iA8G'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "It's Bigger Then Hip Hop radio!  Where we have those HIGHER INFINITE POWER HEALING OUR PEOPLE type conversations with brilliant black minds.  Our show is all about the Hip Hop culture and empowering our people .  While providing great content and guest such as Dr. Dick Gregory, Susan L. Taylor, Dr. Julia Hare, Karen White, Adina Howard, Dr. Steve Perry, John Marshall Jones,Tony Terry, Mama Sol, Nene Ali, Charnele Brown, Mako Girls, Syleena Johnson, D. Channsin Berry, Tabitha Brown, Lina Loi, C.R. Capers, Shaka Senghor, Yahya McClain, Bruce George, Russell Simmons, Brian Barton, Bill Duke..",
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/3GHzMAdBhv9Xhzx0iUiWKE'},
#     'href': 'https://api.spotify.com/v1/shows/3GHzMAdBhv9Xhzx0iUiWKE',
#     'id': '3GHzMAdBhv9Xhzx0iUiWKE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c4ead209b7a6a918b4862406d9682abb6190e0ac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/1bef4dab9dab72f88fe8788c13cac4e548de6bb0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/3ccfe53881952b8a1e6e00c62447ce6e021b6310',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'IBTHHRADIO ',
#     'publisher': 'Jeff Hodges ',
#     'total_episodes': 1,
#     'type': 'show',
#     'uri': 'spotify:show:3GHzMAdBhv9Xhzx0iUiWKE'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': "Just 1 and 7 Billion boah puting his thoughts out there in the aether for those who wanna listen. I'm experimenting with voice as a medium so we'll see how it goes. Support this podcast: https://anchor.fm/the-random-musings-of-cha/support",
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/7dYaO5P8seWZOaZ0wpSl5t'},
#     'href': 'https://api.spotify.com/v1/shows/7dYaO5P8seWZOaZ0wpSl5t',
#     'id': '7dYaO5P8seWZOaZ0wpSl5t',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/dabab1398b63ac22c6bdfb3100df855d21c7143f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4c8d0b3b247abad5cdd992b28e0cddb71158181e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0127383f9282ce647d497f3f637e8269cc0a7eb9',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en-US'],
#     'media_type': 'audio',
#     'name': 'The Random Musings of Chaz Bazz',
#     'publisher': 'Charles Robert Simmons II',
#     'total_episodes': 10,
#     'type': 'show',
#     'uri': 'spotify:show:7dYaO5P8seWZOaZ0wpSl5t'},
#    {'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'copyrights': [],
#     'description': 'HBO and The Ringer’s Bill Simmons hosts the most downloaded sports podcast of all time, with a rotating crew of celebrities, athletes, and media staples, as well as mainstays like Cousin Sal, Joe House, and a slew of other friends and family members who always happen to be suspiciously available. Support this podcast: https://anchor.fm/spg-sampoerna/support',
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/show/4rWTbzq0K3uiFhsDily1m4'},
#     'href': 'https://api.spotify.com/v1/shows/4rWTbzq0K3uiFhsDily1m4',
#     'id': '4rWTbzq0K3uiFhsDily1m4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6cc158cb4968dd5f8003099b8b8a808cf8b16ea6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/915c5ba4a836f9cb312c7bed835dabe2b4a5177f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ee1f91ed8454a6b15be4bd3746a5e55d592b39b5',
#       'width': 64}],
#     'is_externally_hosted': False,
#     'languages': ['en'],
#     'media_type': 'audio',
#     'name': 'The Bill Simmons Podcast',
#     'publisher': 'spg sampoerna',
#     'total_episodes': 24,
#     'type': 'show',
#     'uri': 'spotify:show:4rWTbzq0K3uiFhsDily1m4'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 20}}

# %%
# get podcast info by show id number
spotify.get_podcast_info_by_id("07SjDmKb9iliEzpNcN2xGD")
# Out:
# https://api.spotify.com/v1/shows?ids=07SjDmKb9iliEzpNcN2xGD&market=US
# {'name': 'The Bill Simmons Podcast',
#  'publisher': 'The Ringer & Bill Simmons',
#  'total_episodes': 708,
#  'id': '07SjDmKb9iliEzpNcN2xGD',
#  'media_type': 'audio',
#  'description': "HBO and The Ringer's Bill Simmons hosts the most downloaded sports podcast of all time, with a rotating crew of celebrities, athletes, and media staples, as well as mainstays like Cousin Sal, Joe House, and a slew of other friends and family members who always happen to be suspiciously available.",
#  'external_urls': {'spotify': 'https://open.spotify.com/show/07SjDmKb9iliEzpNcN2xGD'},
#  'languages': ['en'],
#  'uri': 'spotify:show:07SjDmKb9iliEzpNcN2xGD'}

# %%
# get podcast episodes by show id number
test = spotify.get_podcast_episodes_by_id("07SjDmKb9iliEzpNcN2xGD")
# Out:
# https://api.spotify.com/v1/shows/07SjDmKb9iliEzpNcN2xGD/episodes?offset=1&limit=10&market=US

# %%
df = pd.DataFrame()
for i in range(9):
    new_dict = test["items"][i]

# %%
test.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
test["href"]
# Out:
# 'https://api.spotify.com/v1/shows/07SjDmKb9iliEzpNcN2xGD/episodes?offset=1&limit=10&market=US'

# %%
test["items"][3]
# Out:
# {'audio_preview_url': 'https://p.scdn.co/mp3-preview/42aaf312435e4dea5f201af00156a608b36aabce',
#  'description': 'The Ringer’s Bill Simmons is joined by Ryen Russillo to discuss the stunning Jamal Murray performance that has forced a Nuggets-Jazz Game 7, NBA players’ strides in working toward social justice, the Mavericks’ playoff exit on a hopeful note for next season, Lakers Round 2 speculation, broadcast gripes, the Celtics beating the Raptors in Game 1 of the semifinals, Rockets-Thunder, how the Heat match up with the Bucks, a Parent Corner preview, and more.',
#  'duration_ms': 8077845,
#  'explicit': False,
#  'external_urls': {'spotify': 'https://open.spotify.com/episode/5Hnnx5LFCaZfAJ6EFa6z0y'},
#  'href': 'https://api.spotify.com/v1/episodes/5Hnnx5LFCaZfAJ6EFa6z0y',
#  'id': '5Hnnx5LFCaZfAJ6EFa6z0y',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#    'width': 64}],
#  'is_externally_hosted': False,
#  'is_playable': True,
#  'language': 'en',
#  'languages': ['en'],
#  'name': 'Murray Magic, Boston’s Ceiling, Harden’s Big Chance, and Parent Corner With Ryen Russillo',
#  'release_date': '2020-08-31',
#  'release_date_precision': 'day',
#  'type': 'episode',
#  'uri': 'spotify:episode:5Hnnx5LFCaZfAJ6EFa6z0y'}

# %%
test
# Out:
# {'href': 'https://api.spotify.com/v1/shows/07SjDmKb9iliEzpNcN2xGD/episodes?offset=1&limit=10&market=US',
#  'items': [{'audio_preview_url': 'https://p.scdn.co/mp3-preview/340c0145b446263897b72d00475eee55336c26d1',
#    'description': 'The Ringer’s Bill Simmons is joined by Ryen Russillo to discuss the Bucks’ playoff turmoil, whether Giannis will re-sign with the Bucks, the Heat’s rising playoffs expectations, Clippers-Nuggets, Raptors-Celtics, Steve Nash as the Nets head coach, Bill’s son Ben’s first-ever fantasy football draft, and more!',
#    'duration_ms': 7111419,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/7ClLPaD1fQ0CaIz1HYRz5W'},
#    'href': 'https://api.spotify.com/v1/episodes/7ClLPaD1fQ0CaIz1HYRz5W',
#    'id': '7ClLPaD1fQ0CaIz1HYRz5W',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'A Giannis Dilemma, Butler’s Alpha Destiny, the Too-Cool Clips, Kyle Lowry, and Homer Corner With Ryen Russillo',
#    'release_date': '2020-09-07',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:7ClLPaD1fQ0CaIz1HYRz5W'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/03d1396f7d97266be1cfbc3338949c50ba7d2f22',
#    'description': 'The Ringer\'s Bill Simmons reacts to the Raptors\' last-second victory over the Boston Celtics to bring the series to 2-1, as well as the Rockets\' Game 7 against the Thunder (1:13). Then Bill is joined by 3x NBA champion and Miami Heat member Andre Iguodala to discuss joining the Heat in February of 2020; playing with teammates like Duncan Robinson, Tyler Herro, Bam Adebayo, and Jimmy Butler; the toughest NBA players he ever had to guard; pausing the playoffs and the large player meeting that followed; and the U.S. Open, PGA Tour, and more (15:38). Then Bill talks with Bakari Sellers and Van Lathan about the 2020 presidential election, fighting for social justice in America, the coronavirus pandemic, and more (1:06:20). Finally, Bill remembers the great Tom Seaver by reading an essay he wrote about him in 2001 titled "Do I Have Anything Left?" (2:05:50)',
#    'duration_ms': 8464457,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/7xYECpG8KxnfyriOFjShnq'},
#    'href': 'https://api.spotify.com/v1/episodes/7xYECpG8KxnfyriOFjShnq',
#    'id': '7xYECpG8KxnfyriOFjShnq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Featuring Andre Iguodala, Van Lathan, and Bakari Sellers. Plus: RIP, Tom Seaver.\xa0',
#    'release_date': '2020-09-04',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:7xYECpG8KxnfyriOFjShnq'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/69914fbe516f5030847947ce0556f38a73052092',
#    'description': 'The Ringer\'s Bill Simmons talks with Joe House about the Utah Jazz exiting the NBA playoffs in a Game 7 loss to the Denver Nuggets, James Harden\'s "disappearance" during Rockets-Thunder Game 6, and the monumental stakes for Houston in the upcoming Game 7. Plus: Celtics-Raptors, the Heat giving the Bucks trouble, and more (1:25). Then Bill is joined by ESPN\'s fantasy football guru, Matthew Berry, to gear up for the start of the NFL season. They talk top skill-position players, strategies for snake drafts and auctions, stack-worthy NFL offenses, stay-aways, sleepers, and more (50:08).',
#    'duration_ms': 7872000,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/4Jq8owazZHdgTCOnKjL01R'},
#    'href': 'https://api.spotify.com/v1/episodes/4Jq8owazZHdgTCOnKjL01R',
#    'id': '4Jq8owazZHdgTCOnKjL01R',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Denver Lives, Harden vs. CP3, and Matthew Berry’s Fantasy Football Preview | With Joe House',
#    'release_date': '2020-09-02',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:4Jq8owazZHdgTCOnKjL01R'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/42aaf312435e4dea5f201af00156a608b36aabce',
#    'description': 'The Ringer’s Bill Simmons is joined by Ryen Russillo to discuss the stunning Jamal Murray performance that has forced a Nuggets-Jazz Game 7, NBA players’ strides in working toward social justice, the Mavericks’ playoff exit on a hopeful note for next season, Lakers Round 2 speculation, broadcast gripes, the Celtics beating the Raptors in Game 1 of the semifinals, Rockets-Thunder, how the Heat match up with the Bucks, a Parent Corner preview, and more.',
#    'duration_ms': 8077845,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/5Hnnx5LFCaZfAJ6EFa6z0y'},
#    'href': 'https://api.spotify.com/v1/episodes/5Hnnx5LFCaZfAJ6EFa6z0y',
#    'id': '5Hnnx5LFCaZfAJ6EFa6z0y',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Murray Magic, Boston’s Ceiling, Harden’s Big Chance, and Parent Corner With Ryen Russillo',
#    'release_date': '2020-08-31',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:5Hnnx5LFCaZfAJ6EFa6z0y'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/6758b779271b32c973be95be13faced923683e57',
#    'description': "The Ringer’s Bill Simmons sat down with actor Chadwick Boseman to talk about sports movies, making biopics, '42,' 'Draft Day,' 'Black Panther,' '21 Bridges,' NFL, NBA, and more.",
#    'duration_ms': 3226384,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/2phSSKKJV17WbUshXZ9qYL'},
#    'href': 'https://api.spotify.com/v1/episodes/2phSSKKJV17WbUshXZ9qYL',
#    'id': '2phSSKKJV17WbUshXZ9qYL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Chadwick Boseman (Nov. 2019 Interview)',
#    'release_date': '2020-08-29',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:2phSSKKJV17WbUshXZ9qYL'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/429a04d46da2905140f40d4864839e81cd047f8c',
#    'description': "The Ringer’s Bill Simmons is joined by civil rights activist and podcaster DeRay Mckesson to discuss the great strides made by Campaign Zero in police reform, the NBA players’ decision to pause the playoffs in wake of the shooting of Jacob Blake, how NBA teams could make the greatest impact in their own cities, and more (5:50). Then Bill talks with Chris Mannix of Sports Illustrated and DAZN about journalism and media rules in the NBA bubble, Wednesday's meeting with NBA players and coaches, and more (34:20). Finally, Bill talks with L.A. Sparks forward and ESPN radio host Chiney Ogwumike about key subplots as we approach the WNBA playoffs, some heartwarming Kobe Bryant stories, the Clippers' new stadium in Inglewood, the challenges of hosting a live radio/TV show, and more (1:06:25).",
#    'duration_ms': 6625646,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/1Nd3ozVDG6m8vjcDcWPekD'},
#    'href': 'https://api.spotify.com/v1/episodes/1Nd3ozVDG6m8vjcDcWPekD',
#    'id': '1Nd3ozVDG6m8vjcDcWPekD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'The NBA Makes History and Discussions With DeRay Mckesson, Chris Mannix, and Chiney Ogwumike',
#    'release_date': '2020-08-28',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:1Nd3ozVDG6m8vjcDcWPekD'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/ddbfc7109d9e6cbc4b2d1ac6ca5ff899b14327ba',
#    'description': 'The Ringer’s Raja Bell and Logan Murdock react to the Clippers’ merciless win over the Mavericks, some heated exchanges on the court, Paul George’s postgame comments about being “checked out” in the bubble, the Nuggets pulling out a win vs. the Jazz, and more (2:18). Then Bill Simmons talks with The Ringer’s Jonathan Tjarks about the Thunder-Rockets Round 1 playoff series, what the 76ers should be looking to do next, the Nuggets-Jazz series, 2021 NBA draft prospects, and more (38:35). Finally, Bill is joined by ‘SNL’ royalty and TV host Seth Meyers to talk about running a late-night show during the pandemic, his 13 seasons at ‘SNL,’ going back to host the show, NFL excitement, the passing of their friend and colleague Maura Mandt, and more (1:28:13).',
#    'duration_ms': 8152033,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/26ScNaj3gKEowguHeVrdWo'},
#    'href': 'https://api.spotify.com/v1/episodes/26ScNaj3gKEowguHeVrdWo',
#    'id': '26ScNaj3gKEowguHeVrdWo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Clippers Revenge, Houston’s Dilemma, Simmons Trades, and Seth Meyers Returns, With Logan Murdock, Raja Bell, and Jonathan Tjarks',
#    'release_date': '2020-08-26',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:26ScNaj3gKEowguHeVrdWo'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/987cc77556ff3b88599f2e148f1810dc4e7f9d8b',
#    'description': "The Ringer's Bill Simmons is joined by Ryen Russillo to discuss Luka Doncic and the Mavericks' win over the Clippers, tying the series at 2-2; the 76ers getting swept by the Celtics in another disappointing playoff exit; the Jazz working toward upsetting the Nuggets with another win; Round 2 speculations; teams that should be looking to trade in the offseason; Quarantine Corner; and more.",
#    'duration_ms': 8427860,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/4JiAK4bwTNprjvB5QvqriJ'},
#    'href': 'https://api.spotify.com/v1/episodes/4JiAK4bwTNprjvB5QvqriJ',
#    'id': '4JiAK4bwTNprjvB5QvqriJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Luka Legend, Sorry Sixers, Embiid Trades, and Denver’s Future With Ryen Russillo',
#    'release_date': '2020-08-24',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:4JiAK4bwTNprjvB5QvqriJ'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/fe271c869591d4ed1959618ecd39ea889fdea7d0',
#    'description': 'The Ringer’s Bill Simmons is joined by Raja Bell, Ryen Russillo, and Kevin O’Connor discuss Tuesday first few days of NBA playoff basketball, and some of\xa0the top draft prospects, before reacting to the 2021 NBA Draft Lottery (4:35). Then talks with The Ringer’s Nora Princiotti about the approaching 2021 NFL season, how empty NFL stadiums could affect on field play, the “battle” for the Patriots starting QB position, the live music void in the pandemic, music documentaries and more (1:34:15).',
#    'duration_ms': 7923879,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/5vEF7jz91O6MKBq2KGd8uJ'},
#    'href': 'https://api.spotify.com/v1/episodes/5vEF7jz91O6MKBq2KGd8uJ',
#    'id': '5vEF7jz91O6MKBq2KGd8uJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'NBA Lottery Winners, GSW’s Next Move, Philly’s Slide, Cam Newton and Taylor Swift with Raja Bell, Kevin O’Connor, Ryen Russillo and Nora Princiotti',
#    'release_date': '2020-08-21',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:5vEF7jz91O6MKBq2KGd8uJ'},
#   {'audio_preview_url': 'https://p.scdn.co/mp3-preview/a983616b5cbffb3e6c7f18e7224f96ad1a6e870e',
#    'description': 'The Ringer’s Bill Simmons is joined by Joe House fresh off of the Lakers\' Round 1 loss to the Trail Blazers. They also discuss Bucks-Magic, Celtics-76ers, Heat-Pacers, Rockets-Thunder, Game 2 gambling odds, and more (1:55). Then Bill is joined by WWE legend turned executive, "The King of Kings" Triple H to discuss how the WWE adapted to the COVID-19 pandemic so quickly, the impact fans have on pro wrestling, unveiling \'WWE ThunderDome,\' working closely with Vince McMahon, searching for the next WWE superstars, and more (52:54).',
#    'duration_ms': 5954168,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/episode/66clDiGvGvFruN6IITjeND'},
#    'href': 'https://api.spotify.com/v1/episodes/66clDiGvGvFruN6IITjeND',
#    'id': '66clDiGvGvFruN6IITjeND',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c7a6feb492a01ec2de8f9f69e0781761fb9a229',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/03e1d6b2013e99460762b19e54842a78a1451eae',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/2180f881a58393c5873d5c934f3c9d54aa91b4a5',
#      'width': 64}],
#    'is_externally_hosted': False,
#    'is_playable': True,
#    'language': 'en',
#    'languages': ['en'],
#    'name': 'Lakers Panic and NBA Playoff Overreactions With Joe House, Plus Triple H on the WWE’s Crazy 2020',
#    'release_date': '2020-08-19',
#    'release_date_precision': 'day',
#    'type': 'episode',
#    'uri': 'spotify:episode:66clDiGvGvFruN6IITjeND'}],
#  'limit': 10,
#  'next': 'https://api.spotify.com/v1/shows/07SjDmKb9iliEzpNcN2xGD/episodes?offset=11&limit=10&market=US',
#  'offset': 1,
#  'previous': 'https://api.spotify.com/v1/shows/07SjDmKb9iliEzpNcN2xGD/episodes?offset=0&limit=10&market=US',
#  'total': 708}

# %%
# get episodes of podcast by show id number
spotify.get_episodes("07SjDmKb9iliEzpNcN2xGD")
# Out:
# {}

# %%
spotify.search("Something Corp", search_type = "artist")
# Out:
# https://api.spotify.com/v1/search?q=Something+Corp&type=artist&market=US
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Something+Corp&type=artist&market=US&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/71h7GTahhKcSkQ1ayhTvOD'},
#     'followers': {'href': None, 'total': 127987},
#     'genres': ['emo',
#      'neon pop punk',
#      'piano rock',
#      'pop emo',
#      'pop punk',
#      'pop rock'],
#     'href': 'https://api.spotify.com/v1/artists/71h7GTahhKcSkQ1ayhTvOD',
#     'id': '71h7GTahhKcSkQ1ayhTvOD',
#     'images': [{'height': 480,
#       'url': 'https://i.scdn.co/image/5fe4b58edb8b1b9c876bf547e6322170a48f6362',
#       'width': 384},
#      {'height': 250,
#       'url': 'https://i.scdn.co/image/471498d992f04aec37200af29afae1ce7c71d105',
#       'width': 200},
#      {'height': 80,
#       'url': 'https://i.scdn.co/image/5b34238cf129e6e1b5b96476cead3341824f368b',
#       'width': 64}],
#     'name': 'Something Corporate',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:71h7GTahhKcSkQ1ayhTvOD'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1}}

# %%
spotify.get_artist("71h7GTahhKcSkQ1ayhTvOD")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/71h7GTahhKcSkQ1ayhTvOD'},
#  'followers': {'href': None, 'total': 127987},
#  'genres': ['emo',
#   'neon pop punk',
#   'piano rock',
#   'pop emo',
#   'pop punk',
#   'pop rock'],
#  'href': 'https://api.spotify.com/v1/artists/71h7GTahhKcSkQ1ayhTvOD',
#  'id': '71h7GTahhKcSkQ1ayhTvOD',
#  'images': [{'height': 480,
#    'url': 'https://i.scdn.co/image/5fe4b58edb8b1b9c876bf547e6322170a48f6362',
#    'width': 384},
#   {'height': 250,
#    'url': 'https://i.scdn.co/image/471498d992f04aec37200af29afae1ce7c71d105',
#    'width': 200},
#   {'height': 80,
#    'url': 'https://i.scdn.co/image/5b34238cf129e6e1b5b96476cead3341824f368b',
#    'width': 64}],
#  'name': 'Something Corporate',
#  'popularity': 49,
#  'type': 'artist',
#  'uri': 'spotify:artist:71h7GTahhKcSkQ1ayhTvOD'}
